# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikithal2023/Codsoft_Internship/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 25ms/step - loss: 0.6263 - mean_absolute_error: 0.7680 - val_loss: 0.5748 - val_mean_absolute_error: 0.7333
# Epoch 2/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4698 - mean_absolute_error: 0.6616 - val_loss: 0.4313 - val_mean_absolute_error: 0.6307
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3465 - mean_absolute_error: 0.5633 - val_loss: 0.3189 - val_mean_absolute_error: 0.5372
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2533 - mean_absolute_error: 0.4766 - val_loss: 0.2352 - val_mean_absolute_error: 0.4565
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1854 - mean_absolute_error: 0.4036 - val_loss: 0.1757 - val_mean_absolute_error: 0.3894
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1366 - mean_absolute_error: 0.3426 - val_loss: 0.1304 - val_mean_absolute_error: 0.3298
# Epoch 7/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0995 - mean_absolute_error: 0.2870 - val_loss: 0.0937 - val_mean_absolute_error: 0.2724
# Epoch 8/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0696 - mean_absolute_error: 0.2349 - val_loss: 0.0649 - val_mean_absolute_error: 0.2190
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0470 - mean_absolute_error: 0.1876 - val_loss: 0.0433 - val_mean_absolute_error: 0.1738
# Epoch 10/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0309 - mean_absolute_error: 0.1478 - val_loss: 0.0286 - val_mean_absolute_error: 0.1372
# Epoch 11/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0207 - mean_absolute_error: 0.1167 - val_loss: 0.0197 - val_mean_absolute_error: 0.1105
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0153 - mean_absolute_error: 0.0972 - val_loss: 0.0150 - val_mean_absolute_error: 0.0958
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mean_absolute_error: 0.0869 - val_loss: 0.0129 - val_mean_absolute_error: 0.0899
# Epoch 14/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mean_absolute_error: 0.0838 - val_loss: 0.0120 - val_mean_absolute_error: 0.0884
# Epoch 15/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mean_absolute_error: 0.0831 - val_loss: 0.0117 - val_mean_absolute_error: 0.0879
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - mean_absolute_error: 0.0829 - val_loss: 0.0115 - val_mean_absolute_error: 0.0876
# Epoch 17/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0111 - mean_absolute_error: 0.0826 - val_loss: 0.0115 - val_mean_absolute_error: 0.0877
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - mean_absolute_error: 0.0820 - val_loss: 0.0115 - val_mean_absolute_error: 0.0877
# Epoch 19/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0815 - val_loss: 0.0116 - val_mean_absolute_error: 0.0879
# Epoch 20/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0108 - mean_absolute_error: 0.0811 - val_loss: 0.0116 - val_mean_absolute_error: 0.0878
# Epoch 21/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0107 - mean_absolute_error: 0.0808 - val_loss: 0.0115 - val_mean_absolute_error: 0.0876
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0106 - mean_absolute_error: 0.0805 - val_loss: 0.0114 - val_mean_absolute_error: 0.0872
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0106 - mean_absolute_error: 0.0803 - val_loss: 0.0113 - val_mean_absolute_error: 0.0869
# Epoch 24/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0105 - mean_absolute_error: 0.0800 - val_loss: 0.0113 - val_mean_absolute_error: 0.0867
# Epoch 25/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0104 - mean_absolute_error: 0.0796 - val_loss: 0.0111 - val_mean_absolute_error: 0.0863
# Epoch 26/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0103 - mean_absolute_error: 0.0793 - val_loss: 0.0111 - val_mean_absolute_error: 0.0859
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0102 - mean_absolute_error: 0.0789 - val_loss: 0.0110 - val_mean_absolute_error: 0.0858
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0102 - mean_absolute_error: 0.0787 - val_loss: 0.0110 - val_mean_absolute_error: 0.0854
# Epoch 29/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0101 - mean_absolute_error: 0.0783 - val_loss: 0.0108 - val_mean_absolute_error: 0.0850
# Epoch 30/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0779 - val_loss: 0.0108 - val_mean_absolute_error: 0.0847
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0099 - mean_absolute_error: 0.0775 - val_loss: 0.0107 - val_mean_absolute_error: 0.0845
# Epoch 32/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0771 - val_loss: 0.0106 - val_mean_absolute_error: 0.0842
# Epoch 33/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0097 - mean_absolute_error: 0.0767 - val_loss: 0.0106 - val_mean_absolute_error: 0.0838
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0762 - val_loss: 0.0104 - val_mean_absolute_error: 0.0831
# Epoch 35/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0759 - val_loss: 0.0103 - val_mean_absolute_error: 0.0827
# Epoch 36/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0755 - val_loss: 0.0102 - val_mean_absolute_error: 0.0822
# Epoch 37/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0093 - mean_absolute_error: 0.0750 - val_loss: 0.0102 - val_mean_absolute_error: 0.0820
# Epoch 38/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0745 - val_loss: 0.0101 - val_mean_absolute_error: 0.0817
# Epoch 39/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0740 - val_loss: 0.0100 - val_mean_absolute_error: 0.0813
# Epoch 40/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0736 - val_loss: 0.0099 - val_mean_absolute_error: 0.0808
# Epoch 41/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0731 - val_loss: 0.0098 - val_mean_absolute_error: 0.0804
# Epoch 42/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0087 - mean_absolute_error: 0.0726 - val_loss: 0.0097 - val_mean_absolute_error: 0.0800
# Epoch 43/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mean_absolute_error: 0.0721 - val_loss: 0.0096 - val_mean_absolute_error: 0.0796
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0085 - mean_absolute_error: 0.0716 - val_loss: 0.0096 - val_mean_absolute_error: 0.0793
# Epoch 45/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0084 - mean_absolute_error: 0.0711 - val_loss: 0.0095 - val_mean_absolute_error: 0.0789
# Epoch 46/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0083 - mean_absolute_error: 0.0705 - val_loss: 0.0093 - val_mean_absolute_error: 0.0784
# Epoch 47/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0082 - mean_absolute_error: 0.0700 - val_loss: 0.0092 - val_mean_absolute_error: 0.0779
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0080 - mean_absolute_error: 0.0694 - val_loss: 0.0092 - val_mean_absolute_error: 0.0777
# Epoch 49/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0079 - mean_absolute_error: 0.0689 - val_loss: 0.0091 - val_mean_absolute_error: 0.0772
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_absolute_error: 0.0681 - val_loss: 0.0090 - val_mean_absolute_error: 0.0770

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.995590898246591
